# %% [markdown]
# # Pharmaceutical Lab Safety & Compliance Monitoring
#
# This notebook serves as part of the Pharmaceutical Lab Surveillance framework. It is focused on strictly tracking critical safety activities like running, jumping, fainting (lying on the floor), and touching of the face to avoid cross-contamination.
#
# **Dataset Information:** The models for detecting Lab-specific Personal Protective Equipment (PPE) have been customized, trained, and exported using **Roboflow**.

# %% [raw]
# Pose Estimation & Action Recognition

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolo11n-pose.pt")  # load an official model
model = YOLO(r"E:\Optimizing Workplace Compliance and Safety\models\runs\detect\train4\weights\best.pt")  # load a custom model

# Predict with the model
results = model.track(source = r"E:\project_data\Videos\video3.mp4", show = True, save = True)  # predict on an image
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# Collecting lapx>=0.5.2
#   Downloading lapx-0.5.11.post1-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\dines\venv\lib\site-packages (from lapx>=0.5.2) (2.2.1)
# Downloading lapx-0.5.11.post1-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 1.5/1.5 MB 1.8 MB/s eta 0:00:00
# Installing collected packages: lapx
# Successfully installed lapx-0.5.11.post1
#
# requirements: AutoUpdate success  16.1s, installed 1 package: ['lapx>=0.5.2']
# requirements:  Restart runtime or rerun command for updates to take effect
#
# WARNING  Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 315.3ms
# video 1/1 (frame 2/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 182.8ms
# video 1/1 (frame 3/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 256.8ms
# video 1/1 (frame 4/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 139.8ms
# video 1/1 (frame 5/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 175.5ms
# video 1/1 (frame 6/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 182.4ms
# video 1/1 (frame 7/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 162.0ms
# video 1/1 (frame 8/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 168.1ms
# video 1/1 (frame 9/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 145.9ms
# video 1/1 (frame 10/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 148.9ms
# video 1/1 (frame 11/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 124.4ms
# video 1/1 (frame 12/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 244.8ms
# video 1/1 (frame 13/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 159.4ms
# video 1/1 (frame 14/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 148.9ms
# video 1/1 (frame 15/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 610.8ms
# video 1/1 (frame 16/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 800.3ms
# video 1/1 (frame 17/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 303.5ms
# video 1/1 (frame 18/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 273.6ms
# video 1/1 (frame 19/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 302.3ms
# video 1/1 (frame 20/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 179.7ms
# video 1/1 (frame 21/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 177.9ms
# video 1/1 (frame 22/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 188.1ms
# video 1/1 (frame 23/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 379.6ms
# video 1/1 (frame 24/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 265.7ms
# video 1/1 (frame 25/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 214.1ms
# video 1/1 (frame 26/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 229.7ms
# video 1/1 (frame 27/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1874.8ms
# video 1/1 (frame 28/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 877.2ms
# video 1/1 (frame 29/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 542.7ms
# video 1/1 (frame 30/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 354.5ms
# video 1/1 (frame 31/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 243.0ms
# video 1/1 (frame 32/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 221.8ms
# video 1/1 (frame 33/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 364.3ms
# video 1/1 (frame 34/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 220.5ms
# video 1/1 (frame 35/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 210.9ms
# video 1/1 (frame 36/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 307.7ms
# video 1/1 (frame 37/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 239.7ms
# video 1/1 (frame 38/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 185.6ms
# video 1/1 (frame 39/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 3 goggless, 1 no-haircap, 255.9ms
# video 1/1 (frame 40/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 487.4ms
# video 1/1 (frame 41/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 176.3ms
# video 1/1 (frame 42/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 180.4ms
# video 1/1 (frame 43/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 223.6ms
# video 1/1 (frame 44/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 164.9ms
# video 1/1 (frame 45/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 227.8ms
# video 1/1 (frame 46/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 509.8ms
# video 1/1 (frame 47/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 1213.2ms
# video 1/1 (frame 48/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 230.8ms
# video 1/1 (frame 49/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 208.4ms
# video 1/1 (frame 50/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 166.1ms
# video 1/1 (frame 51/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 348.7ms
# video 1/1 (frame 52/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 372.4ms
# video 1/1 (frame 53/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 352.3ms
# video 1/1 (frame 54/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 692.0ms
# video 1/1 (frame 55/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 496.0ms
# video 1/1 (frame 56/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 319.0ms
# video 1/1 (frame 57/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 347.0ms
# video 1/1 (frame 58/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 180.8ms
# video 1/1 (frame 59/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 364.0ms
# video 1/1 (frame 60/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 234.3ms
# video 1/1 (frame 61/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 315.5ms
# video 1/1 (frame 62/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 216.4ms
# video 1/1 (frame 63/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 186.6ms
# video 1/1 (frame 64/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 132.9ms
# video 1/1 (frame 65/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 172.1ms
# video 1/1 (frame 66/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 156.4ms
# video 1/1 (frame 67/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 144.2ms
# video 1/1 (frame 68/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 140.1ms
# video 1/1 (frame 69/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 329.8ms
# video 1/1 (frame 70/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 146.3ms
# video 1/1 (frame 71/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 179.8ms
# video 1/1 (frame 72/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 245.5ms
# video 1/1 (frame 73/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 167.3ms
# video 1/1 (frame 74/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 205.0ms
# video 1/1 (frame 75/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 225.6ms
# video 1/1 (frame 76/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 1 no-haircap, 187.2ms
# video 1/1 (frame 77/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 230.8ms
# video 1/1 (frame 78/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 270.9ms
# video 1/1 (frame 79/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 141.2ms
# video 1/1 (frame 80/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 131.7ms
# video 1/1 (frame 81/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 149.9ms
# video 1/1 (frame 82/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 200.8ms
# video 1/1 (frame 83/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 178.6ms
# video 1/1 (frame 84/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 166.4ms
# video 1/1 (frame 85/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 175.7ms
# video 1/1 (frame 86/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 145.9ms
# video 1/1 (frame 87/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 160.8ms
# video 1/1 (frame 88/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 138.4ms
# video 1/1 (frame 89/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 121.7ms
# video 1/1 (frame 90/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 181.9ms
# video 1/1 (frame 91/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 147.1ms
# video 1/1 (frame 92/1185) E:\project_data\Videos\video3.mp4: 192x320 2 goggless, 1 no-haircap, 171.0ms
# video 1/1 (frame 93/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 128.5ms
# video 1/1 (frame 94/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 122.8ms
# video 1/1 (frame 95/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 126.2ms
# video 1/1 (frame 96/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 122.1ms
# video 1/1 (frame 97/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 122.8ms
# video 1/1 (frame 98/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 124.9ms
# video 1/1 (frame 99/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 123.7ms
# video 1/1 (frame 100/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 133.0ms
# video 1/1 (frame 101/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 218.7ms
# video 1/1 (frame 102/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 117.5ms
# video 1/1 (frame 103/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 3 goggless, 137.6ms
# video 1/1 (frame 104/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 goggless, 1 no-haircap, 126.8ms
# video 1/1 (frame 105/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 119.0ms
# video 1/1 (frame 106/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 118.0ms
# video 1/1 (frame 107/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 goggles, 1 no-haircap, 142.1ms
# video 1/1 (frame 108/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 112.5ms
# video 1/1 (frame 109/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 129.9ms
# video 1/1 (frame 110/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 109.8ms
# video 1/1 (frame 111/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 130.1ms
# video 1/1 (frame 112/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 138.6ms
# video 1/1 (frame 113/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 128.7ms
# video 1/1 (frame 114/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 444.5ms
# video 1/1 (frame 115/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 194.2ms
# video 1/1 (frame 116/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 170.2ms
# video 1/1 (frame 117/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 129.3ms
# video 1/1 (frame 118/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 104.9ms
# video 1/1 (frame 119/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 126.7ms
# video 1/1 (frame 120/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 117.6ms
# video 1/1 (frame 121/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 114.4ms
# video 1/1 (frame 122/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 122.9ms
# video 1/1 (frame 123/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 116.7ms
# video 1/1 (frame 124/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 105.3ms
# video 1/1 (frame 125/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 97.1ms
# video 1/1 (frame 126/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 92.5ms
# video 1/1 (frame 127/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 138.7ms
# video 1/1 (frame 128/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 91.9ms
# video 1/1 (frame 129/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 113.6ms
# video 1/1 (frame 130/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 120.0ms
# video 1/1 (frame 131/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 141.5ms
# video 1/1 (frame 132/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 100.5ms
# video 1/1 (frame 133/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 105.3ms
# video 1/1 (frame 134/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 91.1ms
# video 1/1 (frame 135/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 112.9ms
# video 1/1 (frame 136/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 110.8ms
# video 1/1 (frame 137/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 96.2ms
# video 1/1 (frame 138/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 101.0ms
# video 1/1 (frame 139/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 99.0ms
# video 1/1 (frame 140/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 87.5ms
# video 1/1 (frame 141/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 101.2ms
# video 1/1 (frame 142/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 83.0ms
# video 1/1 (frame 143/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 106.7ms
# video 1/1 (frame 144/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 79.9ms
# video 1/1 (frame 145/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 95.5ms
# video 1/1 (frame 146/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 88.1ms
# video 1/1 (frame 147/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 92.6ms
# video 1/1 (frame 148/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 87.0ms
# video 1/1 (frame 149/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 88.5ms
# video 1/1 (frame 150/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 92.6ms
# video 1/1 (frame 151/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 126.1ms
# video 1/1 (frame 152/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 84.1ms
# video 1/1 (frame 153/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 91.6ms
# video 1/1 (frame 154/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 84.9ms
# video 1/1 (frame 155/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 no-haircap, 85.9ms
# video 1/1 (frame 156/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 no-haircap, 89.5ms
# video 1/1 (frame 157/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 104.2ms
# video 1/1 (frame 158/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 103.4ms
# video 1/1 (frame 159/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 188.1ms
# video 1/1 (frame 160/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 106.9ms
# video 1/1 (frame 161/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 110.8ms
# video 1/1 (frame 162/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 155.4ms
# video 1/1 (frame 163/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 345.8ms
# video 1/1 (frame 164/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 113.6ms
# video 1/1 (frame 165/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 96.6ms
# video 1/1 (frame 166/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 113.6ms
# video 1/1 (frame 167/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 108.8ms
# video 1/1 (frame 168/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 112.5ms
# video 1/1 (frame 169/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 116.8ms
# video 1/1 (frame 170/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 118.9ms
# video 1/1 (frame 171/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 127.2ms
# video 1/1 (frame 172/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 129.8ms
# video 1/1 (frame 173/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 119.8ms
# video 1/1 (frame 174/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 122.3ms
# video 1/1 (frame 175/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 118.0ms
# video 1/1 (frame 176/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 113.3ms
# video 1/1 (frame 177/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 97.6ms
# video 1/1 (frame 178/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 96.1ms
# video 1/1 (frame 179/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 113.7ms
# video 1/1 (frame 180/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 mask, 1 no-gloves, 108.6ms
# video 1/1 (frame 181/1185) E:\project_data\Videos\video3.mp4: 192x320 2 glovess, 1 goggles, 1 no-haircap, 1 no-mask, 112.8ms
# video 1/1 (frame 182/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 105.3ms
# video 1/1 (frame 183/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 113.9ms
# video 1/1 (frame 184/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 107.8ms
# video 1/1 (frame 185/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 112.2ms
# video 1/1 (frame 186/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 97.7ms
# video 1/1 (frame 187/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 99.2ms
# video 1/1 (frame 188/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 118.1ms
# video 1/1 (frame 189/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 110.3ms
# video 1/1 (frame 190/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 125.8ms
# video 1/1 (frame 191/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 118.0ms
# video 1/1 (frame 192/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 117.2ms
# video 1/1 (frame 193/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 99.2ms
# video 1/1 (frame 194/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-gloves, 1 no-haircap, 1 no-mask, 115.4ms
# video 1/1 (frame 195/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-gloves, 1 no-haircap, 1 no-mask, 108.8ms
# video 1/1 (frame 196/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 97.2ms
# video 1/1 (frame 197/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 119.3ms
# video 1/1 (frame 198/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 109.8ms
# video 1/1 (frame 199/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 102.2ms
# video 1/1 (frame 200/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 106.7ms
# video 1/1 (frame 201/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 95.6ms
# video 1/1 (frame 202/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 98.2ms
# video 1/1 (frame 203/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 1 no-mask, 132.9ms
# video 1/1 (frame 204/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 1 no-mask, 132.3ms
# video 1/1 (frame 205/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 no-haircap, 1 no-mask, 108.7ms
# video 1/1 (frame 206/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 126.4ms
# video 1/1 (frame 207/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 110.7ms
# video 1/1 (frame 208/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 129.3ms
# video 1/1 (frame 209/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 2 goggless, 1 no-haircap, 1 no-mask, 119.0ms
# video 1/1 (frame 210/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 117.2ms
# video 1/1 (frame 211/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 156.6ms
# video 1/1 (frame 212/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 130.8ms
# video 1/1 (frame 213/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 104.7ms
# video 1/1 (frame 214/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 120.9ms
# video 1/1 (frame 215/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 1 no-mask, 106.1ms
# video 1/1 (frame 216/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 2 goggless, 1 no-haircap, 1 no-mask, 122.8ms
# video 1/1 (frame 217/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 2 goggless, 1 no-haircap, 1 no-mask, 130.1ms
# video 1/1 (frame 218/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 2 goggless, 1 no-haircap, 1 no-mask, 95.0ms
# video 1/1 (frame 219/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 2 goggless, 1 no-haircap, 1 no-mask, 85.0ms
# video 1/1 (frame 220/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 2 glovess, 3 goggless, 2 haircaps, 1 mask, 1 no-gloves, 1 no-haircap, 82.0ms
# video 1/1 (frame 221/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 84.6ms
# video 1/1 (frame 222/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 84.5ms
# video 1/1 (frame 223/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 102.2ms
# video 1/1 (frame 224/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 80.9ms
# video 1/1 (frame 225/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 78.9ms
# video 1/1 (frame 226/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 96.6ms
# video 1/1 (frame 227/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 104.6ms
# video 1/1 (frame 228/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 105.1ms
# video 1/1 (frame 229/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 94.2ms
# video 1/1 (frame 230/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 84.4ms
# video 1/1 (frame 231/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 100.5ms
# video 1/1 (frame 232/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 99.5ms
# video 1/1 (frame 233/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 82.9ms
# video 1/1 (frame 234/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 92.5ms
# video 1/1 (frame 235/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 99.1ms
# video 1/1 (frame 236/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 97.0ms
# video 1/1 (frame 237/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 91.6ms
# video 1/1 (frame 238/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 92.5ms
# video 1/1 (frame 239/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 76.4ms
# video 1/1 (frame 240/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 91.5ms
# video 1/1 (frame 241/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 89.5ms
# video 1/1 (frame 242/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 84.4ms
# video 1/1 (frame 243/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 93.2ms
# video 1/1 (frame 244/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 110.5ms
# video 1/1 (frame 245/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 97.1ms
# video 1/1 (frame 246/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 254.8ms
# video 1/1 (frame 247/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 145.7ms
# video 1/1 (frame 248/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 no-haircap, 106.7ms
# video 1/1 (frame 249/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 162.1ms
# video 1/1 (frame 250/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 138.0ms
# video 1/1 (frame 251/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 127.8ms
# video 1/1 (frame 252/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 169.1ms
# video 1/1 (frame 253/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 87.9ms
# video 1/1 (frame 254/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 103.1ms
# video 1/1 (frame 255/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 85.0ms
# video 1/1 (frame 256/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 77.9ms
# video 1/1 (frame 257/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 92.7ms
# video 1/1 (frame 258/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 84.9ms
# video 1/1 (frame 259/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 88.1ms
# video 1/1 (frame 260/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 83.4ms
# video 1/1 (frame 261/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 102.9ms
# video 1/1 (frame 262/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 goggles, 1 haircap, 87.1ms
# video 1/1 (frame 263/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 93.6ms
# video 1/1 (frame 264/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 96.1ms
# video 1/1 (frame 265/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 103.2ms
# video 1/1 (frame 266/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 1 haircap, 114.9ms
# video 1/1 (frame 267/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 114.2ms
# video 1/1 (frame 268/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 89.5ms
# video 1/1 (frame 269/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 76.0ms
# video 1/1 (frame 270/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 77.0ms
# video 1/1 (frame 271/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 88.9ms
# video 1/1 (frame 272/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 92.6ms
# video 1/1 (frame 273/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 102.6ms
# video 1/1 (frame 274/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 100.2ms
# video 1/1 (frame 275/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 112.6ms
# video 1/1 (frame 276/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 107.4ms
# video 1/1 (frame 277/1185) E:\project_data\Videos\video3.mp4: 192x320 1 goggles, 102.1ms
# video 1/1 (frame 278/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 134.3ms
# video 1/1 (frame 279/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 107.6ms
# video 1/1 (frame 280/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 121.6ms
# video 1/1 (frame 281/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 108.0ms
# video 1/1 (frame 282/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 172.5ms
# video 1/1 (frame 283/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 221.0ms
# video 1/1 (frame 284/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 121.1ms
# video 1/1 (frame 285/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-gloves, 113.0ms
# video 1/1 (frame 286/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 201.3ms
# video 1/1 (frame 287/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 122.2ms
# video 1/1 (frame 288/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 156.8ms
# video 1/1 (frame 289/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 115.6ms
# video 1/1 (frame 290/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 111.7ms
# video 1/1 (frame 291/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 107.8ms
# video 1/1 (frame 292/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 114.3ms
# video 1/1 (frame 293/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 119.9ms
# video 1/1 (frame 294/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 101.2ms
# video 1/1 (frame 295/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 105.8ms
# video 1/1 (frame 296/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 92.6ms
# video 1/1 (frame 297/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 104.7ms
# video 1/1 (frame 298/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 104.2ms
# video 1/1 (frame 299/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 101.6ms
# video 1/1 (frame 300/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 116.3ms
# video 1/1 (frame 301/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 121.5ms
# video 1/1 (frame 302/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 124.3ms
# video 1/1 (frame 303/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 123.0ms
# video 1/1 (frame 304/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 125.9ms
# video 1/1 (frame 305/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 no-haircap, 108.9ms
# video 1/1 (frame 306/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 no-gloves, 1 no-haircap, 101.4ms
# video 1/1 (frame 307/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-gloves, 1 no-haircap, 114.3ms
# video 1/1 (frame 308/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 137.2ms
# video 1/1 (frame 309/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 102.9ms
# video 1/1 (frame 310/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 113.1ms
# video 1/1 (frame 311/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 112.6ms
# video 1/1 (frame 312/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 no-haircap, 102.2ms
# video 1/1 (frame 313/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 no-haircap, 110.9ms
# video 1/1 (frame 314/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 no-haircap, 113.7ms
# video 1/1 (frame 315/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 105.2ms
# video 1/1 (frame 316/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 no-haircap, 110.7ms
# video 1/1 (frame 317/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 no-haircap, 108.2ms
# video 1/1 (frame 318/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 no-haircap, 111.8ms
# video 1/1 (frame 319/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 no-haircap, 106.8ms
# video 1/1 (frame 320/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 1 goggles, 96.6ms
# video 1/1 (frame 321/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 91.7ms
# video 1/1 (frame 322/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 106.1ms
# video 1/1 (frame 323/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 104.7ms
# video 1/1 (frame 324/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 92.5ms
# video 1/1 (frame 325/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 81.0ms
# video 1/1 (frame 326/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 101.4ms
# video 1/1 (frame 327/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 82.4ms
# video 1/1 (frame 328/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 gloves, 84.5ms
# video 1/1 (frame 329/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 85.5ms
# video 1/1 (frame 330/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 92.6ms
# video 1/1 (frame 331/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 80.0ms
# video 1/1 (frame 332/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 76.4ms
# video 1/1 (frame 333/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 80.9ms
# video 1/1 (frame 334/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 77.8ms
# video 1/1 (frame 335/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 77.9ms
# video 1/1 (frame 336/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 85.9ms
# video 1/1 (frame 337/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 109.5ms
# video 1/1 (frame 338/1185) E:\project_data\Videos\video3.mp4: 192x320 2 full-coats, 1 gloves, 95.6ms
# video 1/1 (frame 339/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 2 glovess, 82.9ms
# video 1/1 (frame 340/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 2 glovess, 78.4ms
# video 1/1 (frame 341/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 2 glovess, 80.4ms
# video 1/1 (frame 342/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 2 glovess, 81.9ms
# video 1/1 (frame 343/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 2 glovess, 77.8ms
# video 1/1 (frame 344/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 2 glovess, 77.4ms
# video 1/1 (frame 345/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 2 glovess, 86.5ms
# video 1/1 (frame 346/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 93.6ms
# video 1/1 (frame 347/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 84.5ms
# video 1/1 (frame 348/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 77.9ms
# video 1/1 (frame 349/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 87.7ms
# video 1/1 (frame 350/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 76.9ms
# video 1/1 (frame 351/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 76.3ms
# video 1/1 (frame 352/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 75.9ms
# video 1/1 (frame 353/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 83.5ms
# video 1/1 (frame 354/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 88.7ms
# video 1/1 (frame 355/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 101.1ms
# video 1/1 (frame 356/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 77.9ms
# video 1/1 (frame 357/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 85.0ms
# video 1/1 (frame 358/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 90.6ms
# video 1/1 (frame 359/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 118.2ms
# video 1/1 (frame 360/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 78.9ms
# video 1/1 (frame 361/1185) E:\project_data\Videos\video3.mp4: 192x320 1 Apron, 1 full-coat, 1 gloves, 80.0ms
# video 1/1 (frame 362/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 78.4ms
# video 1/1 (frame 363/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 90.6ms
# video 1/1 (frame 364/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 83.9ms
# video 1/1 (frame 365/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 78.9ms
# video 1/1 (frame 366/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 78.4ms
# video 1/1 (frame 367/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 80.0ms
# video 1/1 (frame 368/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 91.4ms
# video 1/1 (frame 369/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 78.5ms
# video 1/1 (frame 370/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 88.0ms
# video 1/1 (frame 371/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 89.6ms
# video 1/1 (frame 372/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 96.5ms
# video 1/1 (frame 373/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 79.9ms
# video 1/1 (frame 374/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 80.9ms
# video 1/1 (frame 375/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 81.0ms
# video 1/1 (frame 376/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 90.5ms
# video 1/1 (frame 377/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 89.5ms
# video 1/1 (frame 378/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 79.4ms
# video 1/1 (frame 379/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 77.8ms
# video 1/1 (frame 380/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 82.9ms
# video 1/1 (frame 381/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 90.6ms
# video 1/1 (frame 382/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 104.2ms
# video 1/1 (frame 383/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 92.6ms
# video 1/1 (frame 384/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 98.0ms
# video 1/1 (frame 385/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 99.2ms
# video 1/1 (frame 386/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 94.2ms
# video 1/1 (frame 387/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 93.6ms
# video 1/1 (frame 388/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 107.6ms
# video 1/1 (frame 389/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 97.6ms
# video 1/1 (frame 390/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 103.3ms
# video 1/1 (frame 391/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 114.3ms
# video 1/1 (frame 392/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 108.5ms
# video 1/1 (frame 393/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 91.2ms
# video 1/1 (frame 394/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 95.7ms
# video 1/1 (frame 395/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 106.6ms
# video 1/1 (frame 396/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 113.7ms
# video 1/1 (frame 397/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 107.1ms
# video 1/1 (frame 398/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 111.1ms
# video 1/1 (frame 399/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 121.1ms
# video 1/1 (frame 400/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 110.1ms
# video 1/1 (frame 401/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 105.6ms
# video 1/1 (frame 402/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 94.5ms
# video 1/1 (frame 403/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 110.4ms
# video 1/1 (frame 404/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 97.1ms
# video 1/1 (frame 405/1185) E:\project_data\Videos\video3.mp4: 192x320 1 no-haircap, 102.6ms
# video 1/1 (frame 406/1185) E:\project_data\Videos\video3.mp4: 192x320 1 gloves, 1 no-haircap, 95.5ms
# video 1/1 (frame 407/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 3 goggless, 2 no-haircaps, 116.0ms
# video 1/1 (frame 408/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 117.6ms
# video 1/1 (frame 409/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 79.4ms
# video 1/1 (frame 410/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 85.0ms
# video 1/1 (frame 411/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 79.0ms
# video 1/1 (frame 412/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 80.9ms
# video 1/1 (frame 413/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 82.1ms
# video 1/1 (frame 414/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 92.5ms
# video 1/1 (frame 415/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 80.4ms
# video 1/1 (frame 416/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 98.1ms
# video 1/1 (frame 417/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 83.4ms
# video 1/1 (frame 418/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 81.5ms
# video 1/1 (frame 419/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 80.0ms
# video 1/1 (frame 420/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 78.0ms
# video 1/1 (frame 421/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 78.4ms
# video 1/1 (frame 422/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 85.5ms
# video 1/1 (frame 423/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 89.9ms
# video 1/1 (frame 424/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 77.4ms
# video 1/1 (frame 425/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 87.0ms
# video 1/1 (frame 426/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 84.1ms
# video 1/1 (frame 427/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 80.4ms
# video 1/1 (frame 428/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 86.4ms
# video 1/1 (frame 429/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 80.4ms
# video 1/1 (frame 430/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 85.3ms
# video 1/1 (frame 431/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 91.7ms
# video 1/1 (frame 432/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 81.4ms
# video 1/1 (frame 433/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 81.4ms
# video 1/1 (frame 434/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 76.9ms
# video 1/1 (frame 435/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 82.1ms
# video 1/1 (frame 436/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 92.1ms
# video 1/1 (frame 437/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 78.4ms
# video 1/1 (frame 438/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 78.4ms
# video 1/1 (frame 439/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 83.9ms
# video 1/1 (frame 440/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 152.9ms
# video 1/1 (frame 441/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 136.7ms
# video 1/1 (frame 442/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 118.0ms
# video 1/1 (frame 443/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 166.8ms
# video 1/1 (frame 444/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 1 no-haircap, 106.0ms
# ...
# WARNING: not enough matching points
# video 1/1 (frame 1021/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 50.0ms
# WARNING: not enough matching points
# video 1/1 (frame 1022/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 41.0ms
# WARNING: not enough matching points
# video 1/1 (frame 1023/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 47.2ms
# WARNING: not enough matching points
# video 1/1 (frame 1024/1185) E:\project_data\Videos\video3.mp4: 192x320 1 full-coat, 45.0ms
# video 1/1 (frame 1025/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.5ms
# video 1/1 (frame 1026/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 46.4ms
# video 1/1 (frame 1027/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 44.0ms
# video 1/1 (frame 1028/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 49.0ms
# video 1/1 (frame 1029/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 41.0ms
# video 1/1 (frame 1030/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 41.0ms
# video 1/1 (frame 1031/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 54.0ms
# video 1/1 (frame 1032/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 41.0ms
# video 1/1 (frame 1033/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 39.0ms
# video 1/1 (frame 1034/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 44.0ms
# video 1/1 (frame 1035/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 40.0ms
# video 1/1 (frame 1036/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 43.0ms
# video 1/1 (frame 1037/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 42.0ms
# video 1/1 (frame 1038/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 43.0ms
# video 1/1 (frame 1039/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 48.0ms
# video 1/1 (frame 1040/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 39.0ms
# video 1/1 (frame 1041/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 39.0ms
# video 1/1 (frame 1042/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 48.0ms
# video 1/1 (frame 1043/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 41.0ms
# video 1/1 (frame 1044/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 41.0ms
# video 1/1 (frame 1045/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 53.0ms
# video 1/1 (frame 1046/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 42.0ms
# video 1/1 (frame 1047/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 42.0ms
# video 1/1 (frame 1048/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 48.0ms
# video 1/1 (frame 1049/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.0ms
# video 1/1 (frame 1050/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 42.0ms
# video 1/1 (frame 1051/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 43.0ms
# video 1/1 (frame 1052/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 41.0ms
# video 1/1 (frame 1053/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 51.0ms
# video 1/1 (frame 1054/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 49.5ms
# video 1/1 (frame 1055/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 52.0ms
# video 1/1 (frame 1056/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 50.0ms
# video 1/1 (frame 1057/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 40.0ms
# video 1/1 (frame 1058/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 43.0ms
# video 1/1 (frame 1059/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.0ms
# video 1/1 (frame 1060/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 44.0ms
# video 1/1 (frame 1061/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 39.0ms
# video 1/1 (frame 1062/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.0ms
# video 1/1 (frame 1063/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 40.0ms
# video 1/1 (frame 1064/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 51.4ms
# video 1/1 (frame 1065/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.0ms
# video 1/1 (frame 1066/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 119.7ms
# video 1/1 (frame 1067/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 71.0ms
# video 1/1 (frame 1068/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 52.5ms
# video 1/1 (frame 1069/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 47.0ms
# video 1/1 (frame 1070/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.1ms
# video 1/1 (frame 1071/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 98.7ms
# video 1/1 (frame 1072/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 80.7ms
# video 1/1 (frame 1073/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 65.0ms
# video 1/1 (frame 1074/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.5ms
# video 1/1 (frame 1075/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 46.0ms
# video 1/1 (frame 1076/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 51.0ms
# video 1/1 (frame 1077/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 49.3ms
# video 1/1 (frame 1078/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 48.0ms
# video 1/1 (frame 1079/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 39.0ms
# video 1/1 (frame 1080/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 39.0ms
# video 1/1 (frame 1081/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 47.0ms
# video 1/1 (frame 1082/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 44.0ms
# video 1/1 (frame 1083/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.0ms
# video 1/1 (frame 1084/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 57.0ms
# video 1/1 (frame 1085/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 44.0ms
# video 1/1 (frame 1086/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 49.0ms
# video 1/1 (frame 1087/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 53.0ms
# video 1/1 (frame 1088/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 47.0ms
# video 1/1 (frame 1089/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 48.0ms
# video 1/1 (frame 1090/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 43.0ms
# video 1/1 (frame 1091/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 55.0ms
# video 1/1 (frame 1092/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 42.0ms
# video 1/1 (frame 1093/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 62.9ms
# video 1/1 (frame 1094/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 102.4ms
# video 1/1 (frame 1095/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 79.0ms
# video 1/1 (frame 1096/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 59.2ms
# video 1/1 (frame 1097/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 60.5ms
# video 1/1 (frame 1098/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 56.0ms
# video 1/1 (frame 1099/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 46.0ms
# video 1/1 (frame 1100/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 47.0ms
# video 1/1 (frame 1101/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 42.0ms
# video 1/1 (frame 1102/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.0ms
# video 1/1 (frame 1103/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 42.0ms
# video 1/1 (frame 1104/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 54.0ms
# video 1/1 (frame 1105/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 44.0ms
# video 1/1 (frame 1106/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 41.0ms
# video 1/1 (frame 1107/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 46.0ms
# video 1/1 (frame 1108/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 55.0ms
# video 1/1 (frame 1109/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 54.0ms
# video 1/1 (frame 1110/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 125.8ms
# video 1/1 (frame 1111/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 91.0ms
# video 1/1 (frame 1112/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 45.0ms
# video 1/1 (frame 1113/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 52.0ms
# video 1/1 (frame 1114/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 61.0ms
# video 1/1 (frame 1115/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 157.0ms
# video 1/1 (frame 1116/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 75.7ms
# video 1/1 (frame 1117/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 86.0ms
# video 1/1 (frame 1118/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 82.0ms
# video 1/1 (frame 1119/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 85.8ms
# video 1/1 (frame 1120/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 86.0ms
# video 1/1 (frame 1121/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 84.9ms
# video 1/1 (frame 1122/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 76.6ms
# video 1/1 (frame 1123/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 68.3ms
# video 1/1 (frame 1124/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 97.1ms
# video 1/1 (frame 1125/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 56.0ms
# video 1/1 (frame 1126/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 59.0ms
# video 1/1 (frame 1127/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 60.0ms
# video 1/1 (frame 1128/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 64.0ms
# video 1/1 (frame 1129/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 65.7ms
# video 1/1 (frame 1130/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 65.5ms
# video 1/1 (frame 1131/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 136.6ms
# video 1/1 (frame 1132/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 163.0ms
# video 1/1 (frame 1133/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 136.5ms
# video 1/1 (frame 1134/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 122.2ms
# video 1/1 (frame 1135/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 110.0ms
# video 1/1 (frame 1136/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 110.2ms
# video 1/1 (frame 1137/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 106.9ms
# video 1/1 (frame 1138/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 113.1ms
# video 1/1 (frame 1139/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 118.6ms
# video 1/1 (frame 1140/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 135.3ms
# video 1/1 (frame 1141/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 95.3ms
# video 1/1 (frame 1142/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 110.8ms
# video 1/1 (frame 1143/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 101.2ms
# video 1/1 (frame 1144/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 111.2ms
# video 1/1 (frame 1145/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 105.0ms
# video 1/1 (frame 1146/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 112.9ms
# video 1/1 (frame 1147/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 126.5ms
# video 1/1 (frame 1148/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 165.9ms
# video 1/1 (frame 1149/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 112.7ms
# video 1/1 (frame 1150/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 105.7ms
# video 1/1 (frame 1151/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 114.9ms
# video 1/1 (frame 1152/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 134.0ms
# video 1/1 (frame 1153/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 100.1ms
# video 1/1 (frame 1154/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 123.7ms
# video 1/1 (frame 1155/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 211.8ms
# video 1/1 (frame 1156/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 107.4ms
# video 1/1 (frame 1157/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 89.5ms
# video 1/1 (frame 1158/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 152.7ms
# video 1/1 (frame 1159/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 449.0ms
# video 1/1 (frame 1160/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 300.3ms
# video 1/1 (frame 1161/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 142.1ms
# video 1/1 (frame 1162/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 125.0ms
# video 1/1 (frame 1163/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 124.0ms
# video 1/1 (frame 1164/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 172.8ms
# video 1/1 (frame 1165/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 93.9ms
# video 1/1 (frame 1166/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 82.8ms
# video 1/1 (frame 1167/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 97.9ms
# video 1/1 (frame 1168/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 87.0ms
# video 1/1 (frame 1169/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 94.1ms
# video 1/1 (frame 1170/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 120.4ms
# video 1/1 (frame 1171/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 82.0ms
# video 1/1 (frame 1172/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 127.6ms
# video 1/1 (frame 1173/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 96.3ms
# video 1/1 (frame 1174/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 95.4ms
# video 1/1 (frame 1175/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 92.6ms
# video 1/1 (frame 1176/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 78.5ms
# video 1/1 (frame 1177/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 86.6ms
# video 1/1 (frame 1178/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 101.6ms
# video 1/1 (frame 1179/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 120.6ms
# video 1/1 (frame 1180/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 109.2ms
# video 1/1 (frame 1181/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 89.5ms
# video 1/1 (frame 1182/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 86.4ms
# video 1/1 (frame 1183/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 86.4ms
# video 1/1 (frame 1184/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 81.0ms
# video 1/1 (frame 1185/1185) E:\project_data\Videos\video3.mp4: 192x320 (no detections), 88.5ms
# Speed: 2.8ms preprocess, 94.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs\detect\track2

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load YOLOv8 pose estimation model
model = YOLO("yolov8n-pose.pt")

# Video input and output paths
video_path = r"E:\project_data\Videos\kids_running.mp4"
output_path = r"E:\Optimizing Workplace Compliance and Safety\models\runs\detect\track\output.mp4"

# Open video file
cap = cv2.VideoCapture(video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' for MP4 format
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Function to calculate angle between three points
def calculate_angle(a, b, c):
    """Calculate the angle between three points (a, b, c) where b is the vertex."""
    ba = np.array(a) - np.array(b)
    bc = np.array(c) - np.array(b)
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))  # Clip to avoid floating-point errors
    return np.degrees(angle)

# Function to classify arm-raising based on angles
def classify_arm_raising(keypoints):
    """Detect if a person is raising their arms based on shoulder and elbow angles."""
    if keypoints is None or len(keypoints) < 17:
        return "Unknown"

    left_shoulder, right_shoulder = keypoints[5], keypoints[6]
    left_elbow, right_elbow = keypoints[7], keypoints[8]
    left_wrist, right_wrist = keypoints[9], keypoints[10]

    left_arm_angle = calculate_angle(left_shoulder, left_elbow, left_wrist)
    right_arm_angle = calculate_angle(right_shoulder, right_elbow, right_wrist)

    arm_raised_threshold = 45  # If angle is less than 45°, the arm is raised

    if left_arm_angle < arm_raised_threshold and right_arm_angle < arm_raised_threshold:
        return "Both Arms Raised"
    elif left_arm_angle < arm_raised_threshold:
        return "Left Arm Raised"
    elif right_arm_angle < arm_raised_threshold:
        return "Right Arm Raised"

    return "Arms Down"

# Process video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 pose estimation
    results = model(frame)

    for result in results:
        if hasattr(result, "keypoints") and result.keypoints is not None:
            keypoints = result.keypoints.xy.numpy()

            for kp in keypoints:
                if len(kp) < 17:
                    continue

                arm_status = classify_arm_raising(kp)

                # Draw keypoints
                for x, y in kp:
                    cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 0), -1)

                # Display detected arm status
                cv2.putText(frame, arm_status, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Write processed frame to output video
    out.write(frame)

    # Show the annotated frame (REMOVE THIS IF RUNNING ON SERVER)
    # cv2.imshow("Arm Raising Detection", frame)  # ❌ REMOVE THIS LINE

    # Add delay for keyboard interrupt handling (optional)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Output video saved as: {output_path}")
# Out:
# 0: 384x640 (no detections), 97.0ms
# Speed: 5.1ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 90
#      84     out.write(frame)
#      86     # Show the annotated frame (REMOVE THIS IF RUNNING ON SERVER)
#      87     # cv2.imshow("Arm Raising Detection", frame)  # ❌ REMOVE THIS LINE
#      88
#      89     # Add delay for keyboard interrupt handling (optional)
# ---> 90     if cv2.waitKey(1) & 0xFF == ord('q'):
#      91         break
#      93 # Release resources
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1367: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvWaitKey'

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load YOLOv8 pose estimation model
model = YOLO("yolov8n-pose.pt")  # Ensure the model file is available

# Open video file or webcam
video_path = "input_video.mp4"  # Change to 0 for webcam
cap = cv2.VideoCapture(video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define output video writer
output_path = "output_video.avi"
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Function to check if the person is touching their face
def is_touching_face(keypoints):
    """
    Detects if a person is touching their face based on hand and face keypoints.
    :param keypoints: Array of detected keypoints
    :return: "Touching Face" or "Not Touching Face"
    """
    if keypoints is None or len(keypoints) < 17:
        return "Unknown"

    # Extract keypoints
    nose = keypoints[0]
    left_eye, right_eye = keypoints[1], keypoints[2]
    left_ear, right_ear = keypoints[3], keypoints[4]
    left_wrist, right_wrist = keypoints[9], keypoints[10]

    # Calculate Euclidean distance function
    def distance(pt1, pt2):
        return np.linalg.norm(np.array(pt1) - np.array(pt2))

    # Define a threshold for face touching (10% of frame height)
    touch_threshold = 0.1 * frame_height

    # Check if the wrist is near any face keypoints
    if (distance(left_wrist, nose) < touch_threshold or
        distance(left_wrist, left_eye) < touch_threshold or
        distance(left_wrist, left_ear) < touch_threshold or
        distance(right_wrist, nose) < touch_threshold or
        distance(right_wrist, right_eye) < touch_threshold or
        distance(right_wrist, right_ear) < touch_threshold):
        return "Touching Face"

    return "Not Touching Face"

# Process video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 pose estimation
    results = model(frame)

    for result in results:
        if hasattr(result, "keypoints") and result.keypoints is not None:
            keypoints = result.keypoints.xy.cpu().numpy()  # Extract keypoints

            for kp in keypoints:
                posture = is_touching_face(kp)

                # Draw keypoints
                for x, y in kp:
                    cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 0), -1)

                # Display detected posture
                cv2.putText(frame, posture, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Write processed frame to output video
    out.write(frame)

    # Show the annotated frame
    cv2.imshow("Face Touching Detection", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Output video saved as: {output_path}")

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load YOLOv11 model for pose estimation
model = YOLO("yolo11n-pose.pt")  # Ensure this model supports pose estimation

# Open input video
input_video = "/content/4761432-uhd_2160_4096_25fps.mp4"  # Change this to your video file path
cap = cv2.VideoCapture(input_video)

# Check if video file is opened successfully
if not cap.isOpened():
    print("Error: Could not open video file.")
    exit()

# Get video properties
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define output video writer
output_path = "/content/output_jumping4.mp4"  # Set output path
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Store previous ankle positions to detect jumps
previous_ankle_heights = {}

# Define threshold for detecting jump (relative movement)
jump_threshold = 3  # Adjust based on testing

# Process video frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO pose estimation
    results = model(frame)

    for result in results:
        keypoints = result.keypoints.xy.cpu().numpy()  # Get keypoints

        for person_id, kp in enumerate(keypoints):
            if len(kp) >= 17:  # Ensure all keypoints are available
                left_ankle, right_ankle = kp[15], kp[16]
                left_knee, right_knee = kp[13], kp[14]
                left_hip, right_hip = kp[11], kp[12]

                # Compute average ankle height
                avg_ankle_y = (left_ankle[1] + right_ankle[1]) / 2
                avg_knee_y = (left_knee[1] + right_knee[1]) / 2
                avg_hip_y = (left_hip[1] + right_hip[1]) / 2

                # Retrieve previous ankle position for this person
                prev_ankle_y = previous_ankle_heights.get(person_id, avg_ankle_y)

                # Detect jump: If ankle height has significantly increased (gone up)
                if prev_ankle_y - avg_ankle_y > jump_threshold:
                    action = "Jumping"
                    color = (0, 0, 255)  # Red
                else:
                    action = "Standing"
                    color = (0, 255, 0)  # Green

                # Save the current ankle height for next frame comparison
                previous_ankle_heights[person_id] = avg_ankle_y

                # Draw bounding box and label
                x1, y1, x2, y2 = map(int, result.boxes[person_id].xyxy[0])
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(frame, action, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    # Write processed frame to video
    video_writer.write(frame)

# Release resources
cap.release()
video_writer.release()
print(f"✅ Jumping detection completed. Output saved at: {output_path}")
